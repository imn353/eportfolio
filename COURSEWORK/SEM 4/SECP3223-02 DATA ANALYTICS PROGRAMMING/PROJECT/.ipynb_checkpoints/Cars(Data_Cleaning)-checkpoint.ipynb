# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("cars_2025.csv")

# %%
df
# Out:
#           date_reg        type  maker      model  colour         fuel  \
# 0       2025-01-01     motokar    BYD       Seal   white     electric
# 1       2025-01-01  window_van    Cam   Placer-X  yellow  greendiesel
# 2       2025-01-01         jip  Chery  Jaecoo J7   green       petrol
# 3       2025-01-01         jip  Chery  Jaecoo J7  silver       petrol
# 4       2025-01-01         jip  Chery      Tiggo    grey       petrol
# ...            ...         ...    ...        ...     ...          ...
# 263573  2025-04-30  window_van  Zeekr        009   black     electric
# 263574  2025-04-30  window_van  Zeekr        009   black     electric
# 263575  2025-04-30  window_van  Zeekr        009   black     electric
# 263576  2025-04-30  window_van  Zeekr        009   black     electric
# 263577  2025-04-30  window_van  Zeekr        009   white     electric
#
#                     state
# 0             Rakan Niaga
# 1                   Johor
# 2             Rakan Niaga
# 3             Rakan Niaga
# 4             Rakan Niaga
# ...                   ...
# 263573  W.P. Kuala Lumpur
# 263574  W.P. Kuala Lumpur
# 263575  W.P. Kuala Lumpur
# 263576        Rakan Niaga
# 263577        Rakan Niaga
#
# [263578 rows x 7 columns]

# %%
# get the number of missing data points per column
missing_values_count_cars = df.isnull().sum()
missing_values_count_cars
# Out:
# date_reg    0
# type        0
# maker       0
# model       0
# colour      0
# fuel        0
# state       0
# dtype: int64

# %%
df_duplicate = df[df.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(df_duplicate)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#           date_reg        type       maker     model  colour           fuel  \
# 9       2025-01-01     pick_up        Ford    Ranger   black    greendiesel
# 10      2025-01-01     pick_up        Ford    Ranger   black    greendiesel
# 11      2025-01-01     pick_up        Ford    Ranger   black    greendiesel
# 15      2025-01-01         jip  Great Wall  Haval H6  silver  hybrid_petrol
# 16      2025-01-01         jip  Great Wall  Haval H6  silver  hybrid_petrol
# ...            ...         ...         ...       ...     ...            ...
# 263569  2025-04-30  window_van       Xpeng        X9  silver       electric
# 263570  2025-04-30  window_van       Xpeng        X9   black       electric
# 263574  2025-04-30  window_van       Zeekr       009   black       electric
# 263575  2025-04-30  window_van       Zeekr       009   black       electric
# 263577  2025-04-30  window_van       Zeekr       009   white       electric
#
#                     state
# 9             Rakan Niaga
# 10            Rakan Niaga
# 11            Rakan Niaga
# 15            Rakan Niaga
# 16            Rakan Niaga
# ...                   ...
# 263569        Rakan Niaga
# 263570        Rakan Niaga
# 263574  W.P. Kuala Lumpur
# 263575  W.P. Kuala Lumpur
# 263577        Rakan Niaga
#
# [215141 rows x 7 columns]

# %%
print(df.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 263573    False
# 263574     True
# 263575     True
# 263576    False
# 263577     True
# Length: 263578, dtype: bool

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#           date_reg        type  maker      model  colour         fuel  \
# 0       2025-01-01     motokar    BYD       Seal   white     electric
# 1       2025-01-01  window_van    Cam   Placer-X  yellow  greendiesel
# 2       2025-01-01         jip  Chery  Jaecoo J7   green       petrol
# 3       2025-01-01         jip  Chery  Jaecoo J7  silver       petrol
# 4       2025-01-01         jip  Chery      Tiggo    grey       petrol
# ...            ...         ...    ...        ...     ...          ...
# 263567  2025-04-30  window_van  Xpeng         X9   white     electric
# 263571  2025-04-30  window_van  Zeekr        009   white     electric
# 263572  2025-04-30  window_van  Zeekr        009   white     electric
# 263573  2025-04-30  window_van  Zeekr        009   black     electric
# 263576  2025-04-30  window_van  Zeekr        009   black     electric
#
#                     state
# 0             Rakan Niaga
# 1                   Johor
# 2             Rakan Niaga
# 3             Rakan Niaga
# 4             Rakan Niaga
# ...                   ...
# 263567        Rakan Niaga
# 263571        Rakan Niaga
# 263572  W.P. Kuala Lumpur
# 263573  W.P. Kuala Lumpur
# 263576        Rakan Niaga
#
# [48437 rows x 7 columns]

# %%
df.reset_index(inplace = True)
df
# Out:
#         index    date_reg        type  maker      model  colour         fuel  \
# 0           0  2025-01-01     motokar    BYD       Seal   white     electric
# 1           1  2025-01-01  window_van    Cam   Placer-X  yellow  greendiesel
# 2           2  2025-01-01         jip  Chery  Jaecoo J7   green       petrol
# 3           3  2025-01-01         jip  Chery  Jaecoo J7  silver       petrol
# 4           4  2025-01-01         jip  Chery      Tiggo    grey       petrol
# ...       ...         ...         ...    ...        ...     ...          ...
# 48432  263567  2025-04-30  window_van  Xpeng         X9   white     electric
# 48433  263571  2025-04-30  window_van  Zeekr        009   white     electric
# 48434  263572  2025-04-30  window_van  Zeekr        009   white     electric
# 48435  263573  2025-04-30  window_van  Zeekr        009   black     electric
# 48436  263576  2025-04-30  window_van  Zeekr        009   black     electric
#
#                    state
# 0            Rakan Niaga
# 1                  Johor
# 2            Rakan Niaga
# 3            Rakan Niaga
# 4            Rakan Niaga
# ...                  ...
# 48432        Rakan Niaga
# 48433        Rakan Niaga
# 48434  W.P. Kuala Lumpur
# 48435  W.P. Kuala Lumpur
# 48436        Rakan Niaga
#
# [48437 rows x 8 columns]

# %%
df.drop(df[df['state']=='Rakan Niaga'].index, inplace = True)
df
# Out:
#         index    date_reg        type       maker     model  colour  \
# 1           1  2025-01-01  window_van         Cam  Placer-X  yellow
# 8           8  2025-01-01     pick_up        Ford    Ranger   white
# 9          12  2025-01-01     pick_up        Ford    Ranger   white
# 13         21  2025-01-01     motokar  Great Wall       Ora   green
# 14         22  2025-01-01     motokar       Honda      City    grey
# ...       ...         ...         ...         ...       ...     ...
# 48425  263556  2025-04-30         jip       Xpeng        G6   white
# 48427  263559  2025-04-30         jip       Xpeng        G6   black
# 48430  263563  2025-04-30  window_van       Xpeng        X9   black
# 48434  263572  2025-04-30  window_van       Zeekr       009   white
# 48435  263573  2025-04-30  window_van       Zeekr       009   black
#
#               fuel              state
# 1      greendiesel              Johor
# 8      greendiesel              Johor
# 9           petrol              Johor
# 13        electric              Johor
# 14          petrol              Johor
# ...            ...                ...
# 48425     electric             Melaka
# 48427     electric           Selangor
# 48430     electric  W.P. Kuala Lumpur
# 48434     electric  W.P. Kuala Lumpur
# 48435     electric  W.P. Kuala Lumpur
#
# [22994 rows x 8 columns]

# %%
df.reset_index(inplace = True)
df
# Out:
#        level_0   index    date_reg        type       maker     model  colour  \
# 0            1       1  2025-01-01  window_van         Cam  Placer-X  yellow
# 1            8       8  2025-01-01     pick_up        Ford    Ranger   white
# 2            9      12  2025-01-01     pick_up        Ford    Ranger   white
# 3           13      21  2025-01-01     motokar  Great Wall       Ora   green
# 4           14      22  2025-01-01     motokar       Honda      City    grey
# ...        ...     ...         ...         ...         ...       ...     ...
# 22989    48425  263556  2025-04-30         jip       Xpeng        G6   white
# 22990    48427  263559  2025-04-30         jip       Xpeng        G6   black
# 22991    48430  263563  2025-04-30  window_van       Xpeng        X9   black
# 22992    48434  263572  2025-04-30  window_van       Zeekr       009   white
# 22993    48435  263573  2025-04-30  window_van       Zeekr       009   black
#
#               fuel              state
# 0      greendiesel              Johor
# 1      greendiesel              Johor
# 2           petrol              Johor
# 3         electric              Johor
# 4           petrol              Johor
# ...            ...                ...
# 22989     electric             Melaka
# 22990     electric           Selangor
# 22991     electric  W.P. Kuala Lumpur
# 22992     electric  W.P. Kuala Lumpur
# 22993     electric  W.P. Kuala Lumpur
#
# [22994 rows x 9 columns]

# %%
df.to_csv('cars_cleaned.csv', index=False)
